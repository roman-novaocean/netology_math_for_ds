# %% [markdown]
# ### Центральная предельная теорема
# В этом задании нужно убедиться, что ЦПТ действительно работает

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts

# %% [markdown]
# Создайте случайную величину из любого выбранного вами распределения, для разных значений n сгенерируйте 1000 выборок размера n и постройте гистрограммы средних этих выборок.

# %%
rv = sts.expon(1)
sample = rv.rvs(size=1000)

# %%
x = np.linspace(0,2,100)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=30, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
#параметры запуска: размеры выборок и количество повторов генерации
n1 = 2
n2 = 5
n3 = 10
n4 = 30
n5 = 100
n6 = 1000
n7 = 10000

samples_count = 1000
#массивы для сохранения средних по выборкам
a1 = np.array([])
a2 = np.array([])
a3 = np.array([])
a4 = np.array([])
a5 = np.array([])
a6 = np.array([])
a7 = np.array([])

for number in range(samples_count):
    # на каждом цикле генерируем выборки разных размеров
    sample1 = rv.rvs(size=n1)
    sample2 = rv.rvs(size=n2)
    sample3 = rv.rvs(size=n3)
    sample4 = rv.rvs(size=n4)
    sample5 = rv.rvs(size=n5)
    sample6 = rv.rvs(size=n6)
    sample7 = rv.rvs(size=n7)

    # считаем среднее по каждой выборке и добавляем в массив средних
    a1 = np.append(a1, sample1.mean())
    a2 = np.append(a2, sample2.mean())
    a3 = np.append(a3, sample3.mean())
    a4 = np.append(a4, sample4.mean())
    a5 = np.append(a5, sample5.mean())
    a6 = np.append(a6, sample6.mean())
    a7 = np.append(a7, sample7.mean())

# %%
#строим графики
#подписи для графиков
label_1 = 'sample of ' + str(n1) + ' histogram'
plt.hist(a1, bins=30, density=True, label=label_1)
plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
label_2 = 'sample of ' + str(n2) + ' histogram'
plt.hist(a2, bins=30, density=True, label=label_2)
plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
label_3 = 'sample of ' + str(n3) + ' histogram'
plt.hist(a3, bins=30, density=True, label=label_3)
plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
label_4 = 'sample of ' + str(n4) + ' histogram'
plt.hist(a4, bins=30, density=True, label=label_4)
plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
label_5 = 'sample of ' + str(n5) + ' histogram'
plt.hist(a5, bins=30, density=True, label=label_5)
plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
label_6 = 'sample of ' + str(n6) + ' histogram'
plt.hist(a6, bins=30, density=True, label=label_6)
plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
label_7 = 'sample of ' + str(n7) + ' histogram'
plt.hist(a7, bins=50, density=True, label=label_7)
plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')
